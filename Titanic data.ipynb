# %%
import pandas as pd
Location = "datasets/titanic3.xls"
df = pd.read_excel(Location)
df.columns = ["Class", "Survived", "Name", "Sex", "Age", "Sibsp", "Parch", "Ticket", "Fare", "Cabin", "Embarked", "Boat", "Body", "Home/Dest"]
df.head()
# Out:
#    Class  Survived                                             Name     Sex  \
# 0      1         1                    Allen, Miss. Elisabeth Walton  female
# 1      1         1                   Allison, Master. Hudson Trevor    male
# 2      1         0                     Allison, Miss. Helen Loraine  female
# 3      1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4      1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        Age  Sibsp  Parch  Ticket      Fare    Cabin Embarked Boat   Body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          Home/Dest
# ...

# %%
df.describe()
# Out:
#              Class     Survived          Age        Sibsp        Parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881135     0.498854     0.385027
# std       0.837836     0.486055    14.413500     1.041658     0.865560
# min       1.000000     0.000000     0.166700     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               Fare        Body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %%
df[df['Sex']=="female"]
# Out:
#       Class  Survived                                               Name  \
# 0         1         1                      Allen, Miss. Elisabeth Walton
# 2         1         0                       Allison, Miss. Helen Loraine
# 4         1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 6         1         1                  Andrews, Miss. Kornelia Theodosia
# 8         1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 11        1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 12        1         1                      Aubart, Mme. Leontine Pauline
# 13        1         1                       Barber, Miss. Ellen "Nellie"
# 17        1         1    Baxter, Mrs. James (Helene DeLaudeniere Chaput)
# 18        1         1                              Bazzani, Miss. Albina
# 21        1         1   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 23        1         1                              Bidois, Miss. Rosalie
# ...

# %%
#shows dataset
df[df["Sex"]=="male"]
# Out:
#       Class  Survived                                           Name   Sex  \
# 1         1         1                 Allison, Master. Hudson Trevor  male
# 3         1         0           Allison, Mr. Hudson Joshua Creighton  male
# 5         1         1                            Anderson, Mr. Harry  male
# 7         1         0                         Andrews, Mr. Thomas Jr  male
# 9         1         0                        Artagaveytia, Mr. Ramon  male
# 10        1         0                         Astor, Col. John Jacob  male
# 14        1         1           Barkworth, Mr. Algernon Henry Wilson  male
# 15        1         0                            Baumann, Mr. John D  male
# 16        1         0                       Baxter, Mr. Quigg Edmond  male
# 19        1         0                           Beattie, Mr. Thomson  male
# 20        1         1                  Beckwith, Mr. Richard Leonard  male
# ...

# %%
#df["Survived"] - shows values only of this column
#df["Survived"]==1 shows true or false if Survived column is 1
#code below dataset for those with Survived = 1
df[df["Survived"]==1]
# Out:
#       Class  Survived                                               Name  \
# 0         1         1                      Allen, Miss. Elisabeth Walton
# 1         1         1                     Allison, Master. Hudson Trevor
# 5         1         1                                Anderson, Mr. Harry
# 6         1         1                  Andrews, Miss. Kornelia Theodosia
# 8         1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 11        1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 12        1         1                      Aubart, Mme. Leontine Pauline
# 13        1         1                       Barber, Miss. Ellen "Nellie"
# 14        1         1               Barkworth, Mr. Algernon Henry Wilson
# 17        1         1    Baxter, Mrs. James (Helene DeLaudeniere Chaput)
# 18        1         1                              Bazzani, Miss. Albina
# 20        1         1                      Beckwith, Mr. Richard Leonard
# ...

# %%
df.groupby("Class")["Age"].mean()
# Out:
# Class
# 1    39.159918
# 2    29.506705
# 3    24.816367
# Name: Age, dtype: float64

# %%
df.groupby("Sex").count()
# Out:
#         Class  Survived  Name  Age  Sibsp  Parch  Ticket  Fare  Cabin  \
# Sex
# female    466       466   466  388    466    466     466   466    141
# male      843       843   843  658    843    843     843   842    154
#
#         Embarked  Boat  Body  Home/Dest
# Sex
# female       464   319     8        288
# male         843   167   113        457

# %%
df.groupby("Sex")["Survived"].count()
# Out:
# Sex
# female    466
# male      843
# Name: Survived, dtype: int64

# %%
df.describe()
# Out:
#              Class     Survived          Age        Sibsp        Parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881135     0.498854     0.385027
# std       0.837836     0.486055    14.413500     1.041658     0.865560
# min       1.000000     0.000000     0.166700     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               Fare        Body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %%
df.groupby("Class")["Age"].count()
# Out:
# Class
# 1    284
# 2    261
# 3    501
# Name: Age, dtype: int64

# %%
df[df["Class"]==3]
# Out:
#       Class  Survived                                             Name  \
# 600       3         0                              Abbing, Mr. Anthony
# 601       3         0                    Abbott, Master. Eugene Joseph
# 602       3         0                      Abbott, Mr. Rossmore Edward
# 603       3         1                 Abbott, Mrs. Stanton (Rosa Hunt)
# 604       3         1                      Abelseth, Miss. Karen Marie
# 605       3         1                    Abelseth, Mr. Olaus Jorgensen
# 606       3         1         Abrahamsson, Mr. Abraham August Johannes
# 607       3         1        Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 608       3         0                   Adahl, Mr. Mauritz Nils Martin
# 609       3         0                                  Adams, Mr. John
# 610       3         0   Ahlin, Mrs. Johan (Johanna Persdotter Larsson)
# 611       3         1                        Aks, Master. Philip Frank
# ...

# %%
df.describe()
# Out:
#              Class     Survived          Age        Sibsp        Parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881135     0.498854     0.385027
# std       0.837836     0.486055    14.413500     1.041658     0.865560
# min       1.000000     0.000000     0.166700     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               Fare        Body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %%
total_women = len(df[df["Sex"]=="female"])
total_men = len(df[df["Sex"]=="male"])
total_survived = len(df[df["Survived"]==1])
total_over18 = len(df[df["Age"]>18])
total_firstclass = len(df[df["Class"]==1])
total_secondclass = len(df[df["Class"]==2])
total_thirdclass = len(df[df["Class"]==3])
womensurvived = len(df[(df['Sex']=="female") & (df['Survived'] == 1)])
mensurvived = len(df[(df['Sex']=="male") & (df['Survived'] == 1)])
firstclasssurv = len(df[(df['Class']==1) & (df['Survived'] == 1)])
secondclasssurv = len(df[(df['Class']==2) & (df['Survived'] == 1)])
thirdclasssurv = len(df[(df['Class']==3) & (df['Survived'] == 1)])
adultsurvived = len(df[(df['Age']>18) & (df['Survived'] == 1)])
childsurvived = len(df[(df['Age']<=18) & (df['Survived'] == 1)])
padultsurv = len(df[(df['Age']>18) & (df['Survived'] == 1)]) / len(df[df["Survived"]==1])
pfirstclasssurv = len(df[(df['Class']==1) & (df['Survived'] == 1)]) / len(df[df["Survived"]==1])
pwomansurv = len(df[(df['Sex']=="female") & (df['Survived'] == 1)]) / len(df[df["Survived"]==1])
psurvive = len(df[df["Survived"]==1]) / len(df["Survived"])
psurv_adult_first_female = padultsurv * pfirstclasssurv * pwomansurv * psurvive
denom = (len(df[df["Age"]>18])/len(df["Age"])) * (len(df[df["Class"]==1])/len(df["Class"])) * (len(df[df["Sex"]=="female"])/len(df["Sex"]))

# %%
print(psurv_adult_first_female)
# Out:
# 0.06878411000763941

# %%
def findsurvivor(iswoman, isfirstclass, isadult, survived):
    return iswoman * isfirstclass * isadult * survived

# %%
print(denom)
# Out:
# 0.05724249179180982

# %%
df.groupby("Class").count()
# Out:
#        Survived  Name  Sex  Age  Sibsp  Parch  Ticket  Fare  Cabin  Embarked  \
# Class
# 1           323   323  323  284    323    323     323   323    256       321
# 2           277   277  277  261    277    277     277   277     23       277
# 3           709   709  709  501    709    709     709   708     16       709
#
#        Boat  Body  Home/Dest
# Class
# 1       201    35        289
# 2       112    31        261
# 3       173    55        195

# %%
df.groupby("Sibsp").count()
# Out:
#        Class  Survived  Name  Sex  Age  Parch  Ticket  Fare  Cabin  Embarked  \
# Sibsp
# 0        891       891   891  891  685    891     891   890    171       889
# 1        319       319   319  319  280    319     319   319    110       319
# 2         42        42    42   42   36     42      42    42     10        42
# 3         20        20    20   20   16     20      20    20      4        20
# 4         22        22    22   22   22     22      22    22      0        22
# 5          6         6     6    6    6      6       6     6      0         6
# 8          9         9     9    9    1      9       9     9      0         9
#
#        Boat  Body  Home/Dest
# Sibsp
# 0       297    91        456
# 1       163    25        234
# 2        19     3         31
# 3         4     1          6
# 4         3     0         12
# 5         0     0          6
# 8         0     1          0

# %%
df.groupby("Survived").count()
# Out:
#           Class  Name  Sex  Age  Sibsp  Parch  Ticket  Fare  Cabin  Embarked  \
# Survived
# 0           809   809  809  619    809    809     809   808    102       809
# 1           500   500  500  427    500    500     500   500    193       498
#
#           Boat  Body  Home/Dest
# Survived
# 0            9   121        398
# 1          477     0        347

# %%
total_women = len(df[df["Sex"]=="female"])
total_men = len(df[df["Sex"]=="male"])
total_survived = len(df[df["Survived"]==1])
total_firstclass = len(df[df["Class"]==1])
total_secondclass = len(df[df["Class"]==2])
total_thirdclass = len(df[df["Class"]==3])
total_sibsp0 = len(df[df["Sibsp"]==0])
total_sibsp1 = len(df[df["Sibsp"]==1])
total_sibsp2 = len(df[df["Sibsp"]==2])
womensurvived = len(df[(df['Sex']=="female") & (df['Survived'] == 1)])
mensurvived = len(df[(df['Sex']=="male") & (df['Survived'] == 1)])
firstclasssurv = len(df[(df['Class']==1) & (df['Survived'] == 1)])
secondclasssurv = len(df[(df['Class']==2) & (df['Survived'] == 1)])
thirdclasssurv = len(df[(df['Class']==3) & (df['Survived'] == 1)])
sibsp0surv = len(df[(df['Sibsp']==0) & (df['Survived'] == 1)])
sibsp1surv = len(df[(df['Sibsp']==1) & (df['Survived'] == 1)])
sibsp2surv = len(df[(df['Sibsp']==2) & (df['Survived'] == 1)])

# %%
# man 2ndclass 0sibsp

psurvive = total_survived / len(df["Survived"])
pmansurv = mensurvived/total_survived 
p2ndclasssurv = secondclasssurv/total_survived
psibsp0surv = sibsp0surv/total_survived
denomman2nd0 = (len(df[df["Sex"]=="male"])/len(df["Sex"])) * (len(df[df["Class"]==2])/len(df["Class"])) * (len(df[df["Sibsp"]==0])/len(df["Sibsp"]))
psurv_man2ndsibsp0 = (pmansurv * p2ndclasssurv * psibsp0surv * psurvive)/denomman2nd0
print(psurv_man2ndsibsp0)
# Out:
# 0.19502287459342463

# %%
# woman 3rdclass 1sibsp

psurvive = total_survived / len(df["Survived"])
pwomansurv = womensurvived/total_survived 
p3rdclasssurv = thirdclasssurv/total_survived 
psibsp1surv = sibsp1surv/total_survived
denomwom3rd1 = (len(df[df["Sex"]=="female"])/len(df["Sex"])) * (len(df[df["Class"]==3])/len(df["Class"])) * (len(df[df["Sibsp"]==1])/len(df["Sibsp"]))
psurv_wom3rdsibsp1 = (pwomansurv * p3rdclasssurv * psibsp1surv * psurvive)/denomwom3rd1
print(psurv_wom3rdsibsp1)
# Out:
# 0.6504026872855878

# %%
# man 1stclass 2sibsp

psurvive = total_survived / len(df["Survived"])
pmansurv = mensurvived/total_survived
p1stclasssurv = firstclasssurv/total_survived
psibsp2surv = sibsp2surv/total_survived
denomman1st2 = (len(df[df["Sex"]=="male"])/len(df["Sex"])) * (len(df[df["Class"]==1])/len(df["Class"])) * (len(df[df["Sibsp"]==2])/len(df["Sibsp"]))
psurv_man1stsibsp2 = (pmansurv * p1stclasssurv * psibsp2surv * psurvive)/denomman1st2
print(psurv_man1stsibsp2)
# Out:
# 0.36666492684855667
